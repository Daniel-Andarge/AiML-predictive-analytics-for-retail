# %% [markdown]
# # Data Cleaning and Preprocessing - Sklearn Pipeline

# %%
import sys
import os
import missingno as msno
import matplotlib.pyplot as plt
sys.path.append('../scripts')
from data_loader import *
from sklearn_pipeline import *

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Train Dataset

# %%
# path to the CSV file
filename = 'train.csv'
path = os.path.join('..', 'data/01_raw', filename)

# Load dataset
train_df = load_dataset(path)
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# #### Train - Missing Values and Dtypes

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# ### Train - Visualize Missing Values

# %%
# visualization of missing observations
plt.figure(figsize=(10,8))
msno.matrix(train_df)
plt.show()

# %% [markdown]
# #### Train - Identify Duplicates

# %%
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### ************

# %% [markdown]
# ### Store Dataset

# %%
# path to the CSV file
filename = 'store.csv'
path = os.path.join('..', 'data/01_raw', filename)

# Load dataset
store_df = load_dataset(path)
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %% [markdown]
# #### Store - Missing Values and Dtypes

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %% [markdown]
# #### Store - Visualize Missing Values

# %%
# visualization of missing observations
plt.figure(figsize=(10,8))
msno.matrix(store_df)
plt.show()

# %% [markdown]
# #### Store - Identify Duplicates

# %%
store_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### ************

# %% [markdown]
# ### Test Dataset

# %%
# path to the CSV file
filename = 'test.csv'
path = os.path.join('..', 'data/01_raw', filename)

# Load dataset
test_df = load_dataset(path)
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %% [markdown]
# #### Test - Missing Values and Dtypes

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Test - Visualize Missing Values

# %%
# visualization of missing observations
plt.figure(figsize=(10,8))
msno.matrix(test_df)
plt.show()

# %% [markdown]
# #### Test - Identify Duplicates

# %%
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### ************

# %% [markdown]
# # Sklearn Pipeline -  Data Cleaning and Preprocessing

# %%
train_validate_files = []
output_folder = '../data/02_intermediate'
train_validate_files = preprocess_data(train_df, store_df, output_folder)

# %% [markdown]
# ## Get Processed Dataframes

# %%
processed_train_df = train_validate_files[0]
processed_validation_df = train_validate_files[1]
processed_merged_df = train_validate_files[2]

# %% [markdown]
# ## Verify Processed Dataframes

# %%
processed_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  datetime64[ns]
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  bool
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  int32
#  8   SchoolHoliday              1017209 non-null  bool
#  9   StoreType                  1017209 non-null  int32
#  10  Assortment                 1017209 non-null  int32
#  11  CompetitionDistance        1017209 non-null  float64
#  12  CompetitionOpenSinceMonth  1017209 non-null  float64
# ...

# %%
processed_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 813767 entries, 417683 to 121958
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      813767 non-null  int64
#  1   DayOfWeek                  813767 non-null  int64
#  2   Date                       813767 non-null  datetime64[ns]
#  3   Customers                  813767 non-null  int64
#  4   Open                       813767 non-null  bool
#  5   Promo                      813767 non-null  int64
#  6   StateHoliday               813767 non-null  int32
#  7   SchoolHoliday              813767 non-null  bool
#  8   StoreType                  813767 non-null  int32
#  9   Assortment                 813767 non-null  int32
#  10  CompetitionDistance        813767 non-null  float64
#  11  CompetitionOpenSinceMonth  813767 non-null  float64
#  12  CompetitionOpenSinceYear   813767 non-null  float64
# ...

# %%
processed_validation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203442 entries, 76435 to 260336
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      203442 non-null  int64
#  1   DayOfWeek                  203442 non-null  int64
#  2   Date                       203442 non-null  datetime64[ns]
#  3   Customers                  203442 non-null  int64
#  4   Open                       203442 non-null  bool
#  5   Promo                      203442 non-null  int64
#  6   StateHoliday               203442 non-null  int32
#  7   SchoolHoliday              203442 non-null  bool
#  8   StoreType                  203442 non-null  int32
#  9   Assortment                 203442 non-null  int32
#  10  CompetitionDistance        203442 non-null  float64
#  11  CompetitionOpenSinceMonth  203442 non-null  float64
#  12  CompetitionOpenSinceYear   203442 non-null  float64
# ...
